# %%
import tensorflow as tf
import keras
import tensorflow.keras.backend as K
from keras import backend as K
from keras.utils import to_categorical
import glob
import os
import segmentation_models_3D as sm
import nibabel as nib
import numpy as np
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from scipy.ndimage import zoom
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
# Out:
# 2023-06-10 23:34:56.934560: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-10 23:34:57.068921: E tensorflow/tsl/lib/monitoring/collection_registry.cc:81] Cannot register 2 metrics with the same name: /tensorflow/core/bfc_allocator_delay
# Segmentation Models: using `tf.keras` framework.

# %%
image_dir = '/home/dnn4/pythonCodeArea/soham/New_folder/resized imgs(256)'
mask_dir = '/home/dnn4/pythonCodeArea/soham/New_folder/resized masks(256)'

#'/home/dnn4/pythonCodeArea/soham/New Folder
# image_path_t = glob.glob(r'/home/dnn4/pythonCodeArea/soham/New Folder/resized imgs(256)org/*.nii')
# mask_path_t = glob.glob(r'/home/dnn4/pythonCodeArea/soham/New Folder/resized masks(256)org/*.nii')

image_path_t = glob.glob(image_dir + '/*.nii.gz')
mask_path_t = glob.glob(mask_dir + '/*.nii.gz')

# image_path_t = glob.glob(os.path.join(image_dir, '*.nii'))
# mask_path_t = glob.glob(os.path.join(mask_dir, '*.nii'))

# %%
print("Number of image files:", len(image_path_t))
print("Number of mask files:", len(mask_path_t))

# Print the first few file paths for verification
print("Sample image file paths:")
for i in range(min(5, len(image_path_t))):
    print(image_path_t[i])

print("Sample mask file paths:")
for i in range(min(5, len(mask_path_t))):
    print(mask_path_t[i])
# Out:
# Number of image files: 38
# Number of mask files: 38
# Sample image file paths:
# /home/dnn4/pythonCodeArea/soham/New_folder/resized imgs(256)/K4-img.nii.gz
# /home/dnn4/pythonCodeArea/soham/New_folder/resized imgs(256)/K2-img.nii.gz
# /home/dnn4/pythonCodeArea/soham/New_folder/resized imgs(256)/K15-img.nii.gz
# /home/dnn4/pythonCodeArea/soham/New_folder/resized imgs(256)/K5-img.nii.gz
# /home/dnn4/pythonCodeArea/soham/New_folder/resized imgs(256)/D17-img.nii.gz
# Sample mask file paths:
# /home/dnn4/pythonCodeArea/soham/New_folder/resized masks(256)/D16-seg.nii.gz
# /home/dnn4/pythonCodeArea/soham/New_folder/resized masks(256)/D14-seg.nii.gz
# /home/dnn4/pythonCodeArea/soham/New_folder/resized masks(256)/K9-seg.nii.gz
# /home/dnn4/pythonCodeArea/soham/New_folder/resized masks(256)/K1-seg.nii.gz
# /home/dnn4/pythonCodeArea/soham/New_folder/resized masks(256)/K20-seg.nii.gz

# %%
img_arr=[]
mask_arr=[]
for x in image_path_t:
  im=nib.load(x)
  img=np.array(im.dataobj)
  img_arr.append(img)
for y in mask_path_t:
  ma=nib.load(y)
  mask=np.array(ma.dataobj)
  mask_arr.append(mask)

# %%
input_img=np.array(img_arr)
input_mask=np.array(mask_arr)
input_img=np.stack((input_img,)*3,axis=-1)
input_mask=np.expand_dims(input_mask,axis=-1)
input_img=input_img.astype(np.float32)
input_mask=input_mask.astype(np.float32)
print(input_img.shape)
print(input_mask.shape)
# Out:
# (38, 256, 256, 64, 3)
# (38, 256, 256, 64, 1)

# %%
x_train, x_test, y_train, y_test= train_test_split(input_img,input_mask,test_size=0.2)
print(x_train.shape,y_test.shape)
# Out:
# (30, 256, 256, 64, 3) (8, 256, 256, 64, 1)

# %%
encoder_weights = 'imagenet'
BACKBONE = 'resnet50'  
LR = 0.0001
optim = tf.keras.optimizers.Adam(LR)
metrics = [sm.metrics.IOUScore(), sm.metrics.FScore(),'binary_accuracy','Precision','Recall','AUC']
# Out:
# 2023-06-10 23:35:04.833850: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-10 23:35:04.859066: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-10 23:35:04.859273: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-10 23:35:04.860636: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-10 23:35:04.863051: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-10 23:35:04.863194: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-10 23:35:04.863315: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-10 23:35:05.296325: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-10 23:35:05.296518: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-10 23:35:05.296651: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-10 23:35:05.296765: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1634] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 18592 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:02:00.0, compute capability: 8.6

# %%
preprocess_input = sm.get_preprocessing(BACKBONE)
model = sm.Linknet(BACKBONE,input_shape=(256,256,64,3),
                encoder_weights='imagenet',activation='sigmoid')
model.compile(optimizer = optim, loss=sm.losses.dice_loss, metrics=metrics)

# %%
lrp=ReduceLROnPlateau(monitor="val_loss",  patience=2)
#es=EarlyStopping(patience=2,monitor='iou_score')
call=[lrp]
history=model.fit(x_train,y_train,
         batch_size=1,
         epochs=30,
         validation_data=(x_test,y_test),
         callbacks=call)
# Out:
# Epoch 1/30
# 2023-06-10 23:35:16.406347: I tensorflow/core/grappler/optimizers/generic_layout_optimizer.cc:405] Cancel Transpose nodes around Pad: transpose_before=model_1/bn_data/FusedBatchNormV3-0-0-TransposeNCDHWToNDHWC-LayoutOptimizer pad=model_1/zero_padding3d/Pad transpose_after=model_1/conv0/Conv3D-0-TransposeNDHWCToNCDHW-LayoutOptimizer,gradient_tape/model_1/conv0/Conv3D/Conv3DBackpropFilterV2-0-TransposeNDHWCToNCDHW-LayoutOptimizer,gradient_tape/model_1/conv0/Conv3D/ShapeN-0-TransposeNDHWCToNCDHW-LayoutOptimizer
# 2023-06-10 23:35:20.542097: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8700
# 2023-06-10 23:35:25.290095: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7f4d522fdb50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-06-10 23:35:25.290133: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2023-06-10 23:35:25.293499: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-06-10 23:35:25.402929: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 30/30 [==============================] - ETA: 0s - loss: 0.9902 - iou_score: 0.0049 - f1-score: 0.0098 - binary_accuracy: 0.5100 - precision: 0.0054 - recall: 0.8369 - auc: 0.8076
# 2023-06-10 23:35:52.180427: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 30/30 [==============================] - 46s 346ms/step - loss: 0.9902 - iou_score: 0.0049 - f1-score: 0.0098 - binary_accuracy: 0.5100 - precision: 0.0054 - recall: 0.8369 - auc: 0.8076 - val_loss: 0.9907 - val_iou_score: 0.0047 - val_f1-score: 0.0093 - val_binary_accuracy: 0.6764 - val_precision: 0.0050 - val_recall: 0.4147 - val_auc: 0.5544 - lr: 1.0000e-04
# Epoch 2/30
# 30/30 [==============================] - 7s 219ms/step - loss: 0.9834 - iou_score: 0.0084 - f1-score: 0.0166 - binary_accuracy: 0.8464 - precision: 0.0197 - recall: 0.9646 - auc: 0.9708 - val_loss: 0.9899 - val_iou_score: 0.0051 - val_f1-score: 0.0101 - val_binary_accuracy: 0.6711 - val_precision: 0.0065 - val_recall: 0.5479 - val_auc: 0.6133 - lr: 1.0000e-04
# Epoch 3/30
# 30/30 [==============================] - 7s 219ms/step - loss: 0.9734 - iou_score: 0.0135 - f1-score: 0.0266 - binary_accuracy: 0.9402 - precision: 0.0478 - recall: 0.9366 - auc: 0.9748 - val_loss: 0.9896 - val_iou_score: 0.0052 - val_f1-score: 0.0104 - val_binary_accuracy: 0.9085 - val_precision: 0.0066 - val_recall: 0.1491 - val_auc: 0.5882 - lr: 1.0000e-04
# Epoch 4/30
# 30/30 [==============================] - 7s 220ms/step - loss: 0.9569 - iou_score: 0.0221 - f1-score: 0.0431 - binary_accuracy: 0.9632 - precision: 0.0710 - recall: 0.8712 - auc: 0.9538 - val_loss: 0.9881 - val_iou_score: 0.0060 - val_f1-score: 0.0119 - val_binary_accuracy: 0.8945 - val_precision: 0.0088 - val_recall: 0.2312 - val_auc: 0.7074 - lr: 1.0000e-04
# Epoch 5/30
# 30/30 [==============================] - 7s 222ms/step - loss: 0.9267 - iou_score: 0.0382 - f1-score: 0.0733 - binary_accuracy: 0.9755 - precision: 0.0987 - recall: 0.8214 - auc: 0.9460 - val_loss: 0.9878 - val_iou_score: 0.0061 - val_f1-score: 0.0122 - val_binary_accuracy: 0.9614 - val_precision: 0.0073 - val_recall: 0.0656 - val_auc: 0.7058 - lr: 1.0000e-04
# Epoch 6/30
# 30/30 [==============================] - 7s 226ms/step - loss: 0.8810 - iou_score: 0.0638 - f1-score: 0.1190 - binary_accuracy: 0.9829 - precision: 0.1256 - recall: 0.7284 - auc: 0.9100 - val_loss: 0.9748 - val_iou_score: 0.0128 - val_f1-score: 0.0252 - val_binary_accuracy: 0.8492 - val_precision: 0.0162 - val_recall: 0.6269 - val_auc: 0.8136 - lr: 1.0000e-04
# Epoch 7/30
# 30/30 [==============================] - 7s 229ms/step - loss: 0.8175 - iou_score: 0.1019 - f1-score: 0.1825 - binary_accuracy: 0.9896 - precision: 0.1751 - recall: 0.6073 - auc: 0.8708 - val_loss: 0.9511 - val_iou_score: 0.0253 - val_f1-score: 0.0489 - val_binary_accuracy: 0.8239 - val_precision: 0.0176 - val_recall: 0.7993 - val_auc: 0.8801 - lr: 1.0000e-04
# Epoch 8/30
# 30/30 [==============================] - 7s 232ms/step - loss: 0.7910 - iou_score: 0.1185 - f1-score: 0.2090 - binary_accuracy: 0.9907 - precision: 0.1754 - recall: 0.5145 - auc: 0.8285 - val_loss: 0.9845 - val_iou_score: 0.0078 - val_f1-score: 0.0155 - val_binary_accuracy: 0.9499 - val_precision: 0.0145 - val_recall: 0.1746 - val_auc: 0.6581 - lr: 1.0000e-04
# Epoch 9/30
# 30/30 [==============================] - 7s 232ms/step - loss: 0.7614 - iou_score: 0.1391 - f1-score: 0.2386 - binary_accuracy: 0.9923 - precision: 0.1992 - recall: 0.4628 - auc: 0.7980 - val_loss: 0.9731 - val_iou_score: 0.0138 - val_f1-score: 0.0269 - val_binary_accuracy: 0.9662 - val_precision: 0.0374 - val_recall: 0.3072 - val_auc: 0.6956 - lr: 1.0000e-04
# Epoch 10/30
# 30/30 [==============================] - 7s 233ms/step - loss: 0.7125 - iou_score: 0.1708 - f1-score: 0.2875 - binary_accuracy: 0.9933 - precision: 0.2419 - recall: 0.5109 - auc: 0.8207 - val_loss: 0.9258 - val_iou_score: 0.0393 - val_f1-score: 0.0742 - val_binary_accuracy: 0.9768 - val_precision: 0.0760 - val_recall: 0.4385 - val_auc: 0.7896 - lr: 1.0000e-05
# Epoch 11/30
# 30/30 [==============================] - 7s 234ms/step - loss: 0.6996 - iou_score: 0.1801 - f1-score: 0.3004 - binary_accuracy: 0.9933 - precision: 0.2486 - recall: 0.5392 - auc: 0.8303 - val_loss: 0.8932 - val_iou_score: 0.0584 - val_f1-score: 0.1068 - val_binary_accuracy: 0.9913 - val_precision: 0.1657 - val_recall: 0.2984 - val_auc: 0.7292 - lr: 1.0000e-05
# Epoch 12/30
# 30/30 [==============================] - 7s 233ms/step - loss: 0.6901 - iou_score: 0.1871 - f1-score: 0.3099 - binary_accuracy: 0.9939 - precision: 0.2677 - recall: 0.5167 - auc: 0.8176 - val_loss: 0.8730 - val_iou_score: 0.0712 - val_f1-score: 0.1270 - val_binary_accuracy: 0.9949 - val_precision: 0.3010 - val_recall: 0.2216 - val_auc: 0.6947 - lr: 1.0000e-05
# Epoch 13/30
# 30/30 [==============================] - 7s 234ms/step - loss: 0.6864 - iou_score: 0.1897 - f1-score: 0.3136 - binary_accuracy: 0.9939 - precision: 0.2691 - recall: 0.5208 - auc: 0.8199 - val_loss: 0.8888 - val_iou_score: 0.0635 - val_f1-score: 0.1112 - val_binary_accuracy: 0.9955 - val_precision: 0.3264 - val_recall: 0.1433 - val_auc: 0.6454 - lr: 1.0000e-05
# Epoch 14/30
# 30/30 [==============================] - 7s 235ms/step - loss: 0.6823 - iou_score: 0.1926 - f1-score: 0.3177 - binary_accuracy: 0.9941 - precision: 0.2755 - recall: 0.5118 - auc: 0.8138 - val_loss: 0.9460 - val_iou_score: 0.0290 - val_f1-score: 0.0540 - val_binary_accuracy: 0.9959 - val_precision: 0.3535 - val_recall: 0.0455 - val_auc: 0.5972 - lr: 1.0000e-05
# Epoch 15/30
# 30/30 [==============================] - 7s 236ms/step - loss: 0.6744 - iou_score: 0.1983 - f1-score: 0.3256 - binary_accuracy: 0.9941 - precision: 0.2793 - recall: 0.5290 - auc: 0.8221 - val_loss: 0.9743 - val_iou_score: 0.0132 - val_f1-score: 0.0257 - val_binary_accuracy: 0.9960 - val_precision: 0.2945 - val_recall: 0.0139 - val_auc: 0.5642 - lr: 1.0000e-06
# Epoch 16/30
# 30/30 [==============================] - 7s 236ms/step - loss: 0.6732 - iou_score: 0.1992 - f1-score: 0.3268 - binary_accuracy: 0.9942 - precision: 0.2812 - recall: 0.5286 - auc: 0.8216 - val_loss: 0.9880 - val_iou_score: 0.0061 - val_f1-score: 0.0120 - val_binary_accuracy: 0.9960 - val_precision: 0.2226 - val_recall: 0.0048 - val_auc: 0.5415 - lr: 1.0000e-06
# Epoch 17/30
# 30/30 [==============================] - 7s 236ms/step - loss: 0.6720 - iou_score: 0.2000 - f1-score: 0.3280 - binary_accuracy: 0.9942 - precision: 0.2822 - recall: 0.5299 - auc: 0.8222 - val_loss: 0.9908 - val_iou_score: 0.0047 - val_f1-score: 0.0092 - val_binary_accuracy: 0.9960 - val_precision: 0.2315 - val_recall: 0.0040 - val_auc: 0.5312 - lr: 1.0000e-07
# Epoch 18/30
# 30/30 [==============================] - 7s 235ms/step - loss: 0.6719 - iou_score: 0.2001 - f1-score: 0.3281 - binary_accuracy: 0.9942 - precision: 0.2824 - recall: 0.5300 - auc: 0.8223 - val_loss: 0.9912 - val_iou_score: 0.0044 - val_f1-score: 0.0088 - val_binary_accuracy: 0.9960 - val_precision: 0.2340 - val_recall: 0.0035 - val_auc: 0.5304 - lr: 1.0000e-07
# Epoch 19/30
# 30/30 [==============================] - 7s 236ms/step - loss: 0.6718 - iou_score: 0.2001 - f1-score: 0.3282 - binary_accuracy: 0.9942 - precision: 0.2825 - recall: 0.5300 - auc: 0.8223 - val_loss: 0.9915 - val_iou_score: 0.0043 - val_f1-score: 0.0085 - val_binary_accuracy: 0.9960 - val_precision: 0.2321 - val_recall: 0.0031 - val_auc: 0.5320 - lr: 1.0000e-08
# Epoch 20/30
# 30/30 [==============================] - 7s 236ms/step - loss: 0.6718 - iou_score: 0.2002 - f1-score: 0.3282 - binary_accuracy: 0.9942 - precision: 0.2825 - recall: 0.5300 - auc: 0.8223 - val_loss: 0.9920 - val_iou_score: 0.0041 - val_f1-score: 0.0080 - val_binary_accuracy: 0.9960 - val_precision: 0.2340 - val_recall: 0.0026 - val_auc: 0.5311 - lr: 1.0000e-08
# Epoch 21/30
# 30/30 [==============================] - 7s 236ms/step - loss: 0.6718 - iou_score: 0.2002 - f1-score: 0.3282 - binary_accuracy: 0.9942 - precision: 0.2825 - recall: 0.5300 - auc: 0.8223 - val_loss: 0.9924 - val_iou_score: 0.0038 - val_f1-score: 0.0076 - val_binary_accuracy: 0.9960 - val_precision: 0.2311 - val_recall: 0.0022 - val_auc: 0.5302 - lr: 1.0000e-09
# Epoch 22/30
# 30/30 [==============================] - 7s 236ms/step - loss: 0.6718 - iou_score: 0.2002 - f1-score: 0.3282 - binary_accuracy: 0.9942 - precision: 0.2825 - recall: 0.5300 - auc: 0.8223 - val_loss: 0.9926 - val_iou_score: 0.0037 - val_f1-score: 0.0074 - val_binary_accuracy: 0.9960 - val_precision: 0.2346 - val_recall: 0.0021 - val_auc: 0.5309 - lr: 1.0000e-09
# Epoch 23/30
# 30/30 [==============================] - 7s 235ms/step - loss: 0.6718 - iou_score: 0.2002 - f1-score: 0.3282 - binary_accuracy: 0.9942 - precision: 0.2825 - recall: 0.5301 - auc: 0.8223 - val_loss: 0.9928 - val_iou_score: 0.0036 - val_f1-score: 0.0072 - val_binary_accuracy: 0.9961 - val_precision: 0.2404 - val_recall: 0.0020 - val_auc: 0.5315 - lr: 1.0000e-10
# Epoch 24/30
# 30/30 [==============================] - 7s 235ms/step - loss: 0.6718 - iou_score: 0.2002 - f1-score: 0.3282 - binary_accuracy: 0.9942 - precision: 0.2825 - recall: 0.5301 - auc: 0.8223 - val_loss: 0.9929 - val_iou_score: 0.0036 - val_f1-score: 0.0071 - val_binary_accuracy: 0.9961 - val_precision: 0.2445 - val_recall: 0.0019 - val_auc: 0.5314 - lr: 1.0000e-10
# Epoch 25/30
# 30/30 [==============================] - 7s 236ms/step - loss: 0.6718 - iou_score: 0.2002 - f1-score: 0.3282 - binary_accuracy: 0.9942 - precision: 0.2825 - recall: 0.5301 - auc: 0.8223 - val_loss: 0.9928 - val_iou_score: 0.0036 - val_f1-score: 0.0072 - val_binary_accuracy: 0.9961 - val_precision: 0.2406 - val_recall: 0.0020 - val_auc: 0.5323 - lr: 1.0000e-11
# Epoch 26/30
# 30/30 [==============================] - 7s 235ms/step - loss: 0.6718 - iou_score: 0.2002 - f1-score: 0.3282 - binary_accuracy: 0.9942 - precision: 0.2825 - recall: 0.5301 - auc: 0.8223 - val_loss: 0.9929 - val_iou_score: 0.0036 - val_f1-score: 0.0071 - val_binary_accuracy: 0.9961 - val_precision: 0.2461 - val_recall: 0.0019 - val_auc: 0.5322 - lr: 1.0000e-11
# Epoch 27/30
# 30/30 [==============================] - 7s 235ms/step - loss: 0.6718 - iou_score: 0.2002 - f1-score: 0.3282 - binary_accuracy: 0.9942 - precision: 0.2825 - recall: 0.5300 - auc: 0.8223 - val_loss: 0.9928 - val_iou_score: 0.0036 - val_f1-score: 0.0072 - val_binary_accuracy: 0.9961 - val_precision: 0.2429 - val_recall: 0.0020 - val_auc: 0.5328 - lr: 1.0000e-12
# Epoch 28/30
# 30/30 [==============================] - 7s 236ms/step - loss: 0.6718 - iou_score: 0.2002 - f1-score: 0.3282 - binary_accuracy: 0.9942 - precision: 0.2825 - recall: 0.5300 - auc: 0.8223 - val_loss: 0.9929 - val_iou_score: 0.0036 - val_f1-score: 0.0071 - val_binary_accuracy: 0.9961 - val_precision: 0.2473 - val_recall: 0.0019 - val_auc: 0.5327 - lr: 1.0000e-12
# Epoch 29/30
# 30/30 [==============================] - 7s 233ms/step - loss: 0.6718 - iou_score: 0.2002 - f1-score: 0.3282 - binary_accuracy: 0.9942 - precision: 0.2825 - recall: 0.5300 - auc: 0.8223 - val_loss: 0.9930 - val_iou_score: 0.0035 - val_f1-score: 0.0070 - val_binary_accuracy: 0.9961 - val_precision: 0.2440 - val_recall: 0.0019 - val_auc: 0.5323 - lr: 1.0000e-13
# Epoch 30/30
# 30/30 [==============================] - 7s 234ms/step - loss: 0.6718 - iou_score: 0.2002 - f1-score: 0.3282 - binary_accuracy: 0.9942 - precision: 0.2825 - recall: 0.5300 - auc: 0.8223 - val_loss: 0.9930 - val_iou_score: 0.0035 - val_f1-score: 0.0070 - val_binary_accuracy: 0.9961 - val_precision: 0.2434 - val_recall: 0.0018 - val_auc: 0.5322 - lr: 1.0000e-13

# %%
#model.evaluate(x_test,y_test)
#score= model.evaluate(x_train,y_train,verbose=0)
results = model.evaluate(x_test, y_test, verbose=0)

# Retrieve and print all metrics
metrics_names = model.metrics_names
for metric_name, metric_value in zip(metrics_names, results):
    print(f"{metric_name}: {metric_value}")
# Out:
# loss: 0.9926682710647583
# iou_score: 0.0036793581675738096
# f1-score: 0.007331740576773882
# binary_accuracy: 0.9960528612136841
# precision: 0.24260957539081573
# recall: 0.001803918625228107
# auc: 0.2949334383010864

# %%
test_img = x_train[0]
ground_truth=y_train[0]
test_img_input=np.expand_dims(test_img, 0)
test_pred1 = model.predict(test_img_input)
test_prediction1=(test_pred1>=0.5)
test_prediction1=np.squeeze(test_prediction1,axis=-1)
test_prediction1=np.squeeze(test_prediction1,axis=0)
print(test_prediction1.shape)
# Out:
# 1/1 [==============================] - 1s 658ms/step
# (256, 256, 64)

# %%
ground_truth_argmax = ground_truth>=0.5
ground_truth_argmax = np.squeeze(ground_truth_argmax, axis = -1)
print(ground_truth_argmax.shape)
print(test_img.shape)
# Out:
# (256, 256, 64)
# (256, 256, 64, 3)

# %%
for x in range(32):
  plt.figure(figsize=(10,10)) 
  plt.subplot(221)
  plt.title('Testing Label')
  plt.imshow(ground_truth_argmax[:,:,x])
  plt.subplot(222)
  plt.title('Prediction on test image')
  plt.imshow(test_prediction1[:,:,x])
  plt.show()

# %%
test_img=nib.load(r"/home/dnn4/pythonCodeArea/soham/New_folder/resized imgs(256)/K1-img.nii.gz")
test_im=np.array(test_img.dataobj)
test_img_input=np.stack((test_im,)*3, -1)
test_img_input=np.expand_dims(test_img_input,0)
print(test_img_input.shape)
test_pred1 = model.predict(test_img_input)
test_pred1=(test_pred1>=0.5)
#test_prediction1 = np.argmax(test_pred1, axis=4)
print(test_prediction1.shape)
print(np.unique(test_pred1))
# Out:
# (1, 256, 256, 64, 3)
# 1/1 [==============================] - 1s 630ms/step
# (256, 256, 64)
# [False  True]

# %%
reconstructed_image=np.reshape(test_pred1,(256,256,64))
reconstructed_image=reconstructed_image.astype(np.uint8)

# %%
print(test_img.affine)
# Out:
# [[   2.          0.          0.       -127.      ]
#  [   0.          2.          0.       -127.      ]
#  [   0.          0.         16.546875 -481.953125]
#  [   0.          0.          0.          1.      ]]

# %%
out_img=nib.Nifti1Image(reconstructed_image,test_img.affine)
nib.save(out_img,'segmentation-output-k1-resnet50')
