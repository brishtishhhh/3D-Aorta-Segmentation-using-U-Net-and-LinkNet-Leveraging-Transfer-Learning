# %%
import tensorflow as tf
import keras
import tensorflow.keras.backend as K
from keras import backend as K
from keras.utils import to_categorical
import glob
import os
import segmentation_models_3D as sm
import nibabel as nib
import numpy as np
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from scipy.ndimage import zoom
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
# Out:
# 2023-06-10 23:48:56.741650: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-10 23:48:56.899039: E tensorflow/tsl/lib/monitoring/collection_registry.cc:81] Cannot register 2 metrics with the same name: /tensorflow/core/bfc_allocator_delay
# Segmentation Models: using `tf.keras` framework.

# %%
image_dir = '/home/dnn4/pythonCodeArea/soham/New_folder/resized imgs(256)'
mask_dir = '/home/dnn4/pythonCodeArea/soham/New_folder/resized masks(256)'

#'/home/dnn4/pythonCodeArea/soham/New Folder
# image_path_t = glob.glob(r'/home/dnn4/pythonCodeArea/soham/New Folder/resized imgs(256)org/*.nii')
# mask_path_t = glob.glob(r'/home/dnn4/pythonCodeArea/soham/New Folder/resized masks(256)org/*.nii')

image_path_t = glob.glob(image_dir + '/*.nii.gz')
mask_path_t = glob.glob(mask_dir + '/*.nii.gz')

# image_path_t = glob.glob(os.path.join(image_dir, '*.nii'))
# mask_path_t = glob.glob(os.path.join(mask_dir, '*.nii'))

# %%
print("Number of image files:", len(image_path_t))
print("Number of mask files:", len(mask_path_t))

# Print the first few file paths for verification
print("Sample image file paths:")
for i in range(min(5, len(image_path_t))):
    print(image_path_t[i])

print("Sample mask file paths:")
for i in range(min(5, len(mask_path_t))):
    print(mask_path_t[i])
# Out:
# Number of image files: 38
# Number of mask files: 38
# Sample image file paths:
# /home/dnn4/pythonCodeArea/soham/New_folder/resized imgs(256)/K4-img.nii.gz
# /home/dnn4/pythonCodeArea/soham/New_folder/resized imgs(256)/K2-img.nii.gz
# /home/dnn4/pythonCodeArea/soham/New_folder/resized imgs(256)/K15-img.nii.gz
# /home/dnn4/pythonCodeArea/soham/New_folder/resized imgs(256)/K5-img.nii.gz
# /home/dnn4/pythonCodeArea/soham/New_folder/resized imgs(256)/D17-img.nii.gz
# Sample mask file paths:
# /home/dnn4/pythonCodeArea/soham/New_folder/resized masks(256)/D16-seg.nii.gz
# /home/dnn4/pythonCodeArea/soham/New_folder/resized masks(256)/D14-seg.nii.gz
# /home/dnn4/pythonCodeArea/soham/New_folder/resized masks(256)/K9-seg.nii.gz
# /home/dnn4/pythonCodeArea/soham/New_folder/resized masks(256)/K1-seg.nii.gz
# /home/dnn4/pythonCodeArea/soham/New_folder/resized masks(256)/K20-seg.nii.gz

# %%
img_arr=[]
mask_arr=[]
for x in image_path_t:
  im=nib.load(x)
  img=np.array(im.dataobj)
  img_arr.append(img)
for y in mask_path_t:
  ma=nib.load(y)
  mask=np.array(ma.dataobj)
  mask_arr.append(mask)

# %%
input_img=np.array(img_arr)
input_mask=np.array(mask_arr)
input_img=np.stack((input_img,)*3,axis=-1)
input_mask=np.expand_dims(input_mask,axis=-1)
input_img=input_img.astype(np.float32)
input_mask=input_mask.astype(np.float32)
print(input_img.shape)
print(input_mask.shape)
# Out:
# (38, 256, 256, 64, 3)
# (38, 256, 256, 64, 1)

# %%
x_train, x_test, y_train, y_test= train_test_split(input_img,input_mask,test_size=0.2)
print(x_train.shape,y_test.shape)
# Out:
# (30, 256, 256, 64, 3) (8, 256, 256, 64, 1)

# %%
encoder_weights = 'imagenet'
BACKBONE = 'resnet50'  
LR = 0.0001
optim = tf.keras.optimizers.Adam(LR)
metrics = [sm.metrics.IOUScore(), sm.metrics.FScore(),'binary_accuracy','Precision','Recall','AUC']
# Out:
# 2023-06-10 23:49:05.428756: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-10 23:49:05.456776: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-10 23:49:05.456989: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-10 23:49:05.458536: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE3 SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-10 23:49:05.460950: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-10 23:49:05.461089: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-10 23:49:05.461208: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-10 23:49:05.950135: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-10 23:49:05.950335: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-10 23:49:05.950468: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-10 23:49:05.950584: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1634] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 18592 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:02:00.0, compute capability: 8.6

# %%
preprocess_input = sm.get_preprocessing(BACKBONE)
model = sm.Unet(BACKBONE,input_shape=(256,256,64,3),
                encoder_weights='imagenet',activation='sigmoid')
model.compile(optimizer = optim, loss=sm.losses.dice_loss, metrics=metrics)

# %%
lrp=ReduceLROnPlateau(monitor="val_loss",  patience=2)
#es=EarlyStopping(patience=2,monitor='iou_score')
call=[lrp]
history=model.fit(x_train,y_train,
         batch_size=1,
         epochs=30,
         validation_data=(x_test,y_test),
         callbacks=call)
# Out:
# Epoch 1/30
# 2023-06-10 23:49:17.266959: I tensorflow/core/grappler/optimizers/generic_layout_optimizer.cc:405] Cancel Transpose nodes around Pad: transpose_before=model_1/bn_data/FusedBatchNormV3-0-0-TransposeNCDHWToNDHWC-LayoutOptimizer pad=model_1/zero_padding3d/Pad transpose_after=model_1/conv0/Conv3D-0-TransposeNDHWCToNCDHW-LayoutOptimizer,gradient_tape/model_1/conv0/Conv3D/Conv3DBackpropFilterV2-0-TransposeNDHWCToNCDHW-LayoutOptimizer,gradient_tape/model_1/conv0/Conv3D/ShapeN-0-TransposeNDHWCToNCDHW-LayoutOptimizer
# 2023-06-10 23:49:21.529281: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8700
# 2023-06-10 23:49:27.665137: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7fe042669cb0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-06-10 23:49:27.665170: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2023-06-10 23:49:27.668504: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-06-10 23:49:27.775491: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 30/30 [==============================] - ETA: 0s - loss: 0.9864 - iou_score: 0.0069 - f1-score: 0.0136 - binary_accuracy: 0.7792 - precision: 0.0125 - recall: 0.8507 - auc: 0.8932
# 2023-06-10 23:49:57.206081: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 30/30 [==============================] - 53s 472ms/step - loss: 0.9864 - iou_score: 0.0069 - f1-score: 0.0136 - binary_accuracy: 0.7792 - precision: 0.0125 - recall: 0.8507 - auc: 0.8932 - val_loss: 0.9879 - val_iou_score: 0.0061 - val_f1-score: 0.0121 - val_binary_accuracy: 0.4695 - val_precision: 0.0061 - val_recall: 0.8826 - val_auc: 0.8211 - lr: 1.0000e-04
# Epoch 2/30
# 30/30 [==============================] - 8s 283ms/step - loss: 0.9760 - iou_score: 0.0122 - f1-score: 0.0240 - binary_accuracy: 0.9251 - precision: 0.0388 - recall: 0.9215 - auc: 0.9678 - val_loss: 0.9814 - val_iou_score: 0.0094 - val_f1-score: 0.0186 - val_binary_accuracy: 0.7758 - val_precision: 0.0137 - val_recall: 0.8502 - val_auc: 0.8507 - lr: 1.0000e-04
# Epoch 3/30
# 30/30 [==============================] - 9s 285ms/step - loss: 0.9618 - iou_score: 0.0195 - f1-score: 0.0382 - binary_accuracy: 0.9557 - precision: 0.0606 - recall: 0.8661 - auc: 0.9613 - val_loss: 0.9793 - val_iou_score: 0.0105 - val_f1-score: 0.0207 - val_binary_accuracy: 0.9083 - val_precision: 0.0204 - val_recall: 0.5116 - val_auc: 0.6913 - lr: 1.0000e-04
# Epoch 4/30
# 30/30 [==============================] - 9s 286ms/step - loss: 0.9357 - iou_score: 0.0333 - f1-score: 0.0643 - binary_accuracy: 0.9717 - precision: 0.0900 - recall: 0.8400 - auc: 0.9523 - val_loss: 0.9797 - val_iou_score: 0.0103 - val_f1-score: 0.0203 - val_binary_accuracy: 0.8180 - val_precision: 0.0131 - val_recall: 0.6570 - val_auc: 0.7527 - lr: 1.0000e-04
# Epoch 5/30
# 30/30 [==============================] - 9s 289ms/step - loss: 0.8937 - iou_score: 0.0565 - f1-score: 0.1063 - binary_accuracy: 0.9809 - precision: 0.1177 - recall: 0.7467 - auc: 0.9302 - val_loss: 0.9760 - val_iou_score: 0.0122 - val_f1-score: 0.0240 - val_binary_accuracy: 0.8587 - val_precision: 0.0148 - val_recall: 0.5749 - val_auc: 0.7481 - lr: 1.0000e-04
# Epoch 6/30
# 30/30 [==============================] - 9s 292ms/step - loss: 0.8357 - iou_score: 0.0903 - f1-score: 0.1643 - binary_accuracy: 0.9882 - precision: 0.1655 - recall: 0.6492 - auc: 0.9026 - val_loss: 0.9843 - val_iou_score: 0.0080 - val_f1-score: 0.0157 - val_binary_accuracy: 0.9937 - val_precision: 0.1086 - val_recall: 0.0984 - val_auc: 0.5459 - lr: 1.0000e-04
# Epoch 7/30
# 30/30 [==============================] - 9s 294ms/step - loss: 0.7830 - iou_score: 0.1233 - f1-score: 0.2170 - binary_accuracy: 0.9909 - precision: 0.1944 - recall: 0.5723 - auc: 0.8702 - val_loss: 0.9676 - val_iou_score: 0.0169 - val_f1-score: 0.0324 - val_binary_accuracy: 0.9934 - val_precision: 0.1381 - val_recall: 0.1513 - val_auc: 0.7342 - lr: 1.0000e-04
# Epoch 8/30
# 30/30 [==============================] - 9s 297ms/step - loss: 0.7657 - iou_score: 0.1352 - f1-score: 0.2343 - binary_accuracy: 0.9914 - precision: 0.1961 - recall: 0.5248 - auc: 0.8297 - val_loss: 0.9377 - val_iou_score: 0.0328 - val_f1-score: 0.0623 - val_binary_accuracy: 0.9895 - val_precision: 0.0879 - val_recall: 0.2000 - val_auc: 0.6765 - lr: 1.0000e-04
# Epoch 9/30
# 30/30 [==============================] - 9s 298ms/step - loss: 0.7168 - iou_score: 0.1674 - f1-score: 0.2832 - binary_accuracy: 0.9928 - precision: 0.2302 - recall: 0.5171 - auc: 0.8181 - val_loss: 0.8486 - val_iou_score: 0.0830 - val_f1-score: 0.1514 - val_binary_accuracy: 0.9917 - val_precision: 0.1838 - val_recall: 0.3679 - val_auc: 0.6880 - lr: 1.0000e-04
# Epoch 10/30
# 30/30 [==============================] - 9s 298ms/step - loss: 0.7014 - iou_score: 0.1783 - f1-score: 0.2986 - binary_accuracy: 0.9939 - precision: 0.2561 - recall: 0.4601 - auc: 0.7802 - val_loss: 0.9214 - val_iou_score: 0.0440 - val_f1-score: 0.0786 - val_binary_accuracy: 0.9950 - val_precision: 0.2164 - val_recall: 0.1385 - val_auc: 0.5622 - lr: 1.0000e-04
# Epoch 11/30
# 30/30 [==============================] - 9s 299ms/step - loss: 0.6693 - iou_score: 0.2041 - f1-score: 0.3307 - binary_accuracy: 0.9946 - precision: 0.2938 - recall: 0.4737 - auc: 0.7890 - val_loss: 0.9389 - val_iou_score: 0.0350 - val_f1-score: 0.0611 - val_binary_accuracy: 0.9953 - val_precision: 0.2124 - val_recall: 0.1024 - val_auc: 0.5353 - lr: 1.0000e-04
# Epoch 12/30
# 30/30 [==============================] - 9s 300ms/step - loss: 0.6378 - iou_score: 0.2250 - f1-score: 0.3622 - binary_accuracy: 0.9947 - precision: 0.3136 - recall: 0.5180 - auc: 0.8125 - val_loss: 0.9331 - val_iou_score: 0.0375 - val_f1-score: 0.0669 - val_binary_accuracy: 0.9956 - val_precision: 0.2282 - val_recall: 0.0877 - val_auc: 0.5450 - lr: 1.0000e-05
# Epoch 13/30
# 30/30 [==============================] - 9s 300ms/step - loss: 0.6129 - iou_score: 0.2440 - f1-score: 0.3871 - binary_accuracy: 0.9952 - precision: 0.3444 - recall: 0.5274 - auc: 0.8159 - val_loss: 0.9230 - val_iou_score: 0.0417 - val_f1-score: 0.0770 - val_binary_accuracy: 0.9957 - val_precision: 0.2356 - val_recall: 0.0817 - val_auc: 0.5491 - lr: 1.0000e-05
# Epoch 14/30
# 30/30 [==============================] - 9s 299ms/step - loss: 0.6028 - iou_score: 0.2523 - f1-score: 0.3972 - binary_accuracy: 0.9955 - precision: 0.3648 - recall: 0.5195 - auc: 0.8123 - val_loss: 0.9363 - val_iou_score: 0.0345 - val_f1-score: 0.0637 - val_binary_accuracy: 0.9958 - val_precision: 0.2376 - val_recall: 0.0631 - val_auc: 0.5338 - lr: 1.0000e-06
# Epoch 15/30
# 30/30 [==============================] - 9s 300ms/step - loss: 0.5982 - iou_score: 0.2556 - f1-score: 0.4018 - binary_accuracy: 0.9955 - precision: 0.3704 - recall: 0.5207 - auc: 0.8137 - val_loss: 0.9475 - val_iou_score: 0.0286 - val_f1-score: 0.0525 - val_binary_accuracy: 0.9959 - val_precision: 0.2299 - val_recall: 0.0487 - val_auc: 0.5249 - lr: 1.0000e-06
# Epoch 16/30
# 30/30 [==============================] - 9s 299ms/step - loss: 0.5953 - iou_score: 0.2578 - f1-score: 0.4047 - binary_accuracy: 0.9956 - precision: 0.3734 - recall: 0.5230 - auc: 0.8148 - val_loss: 0.9549 - val_iou_score: 0.0248 - val_f1-score: 0.0451 - val_binary_accuracy: 0.9960 - val_precision: 0.2320 - val_recall: 0.0409 - val_auc: 0.5175 - lr: 1.0000e-07
# Epoch 17/30
# 30/30 [==============================] - 9s 299ms/step - loss: 0.5951 - iou_score: 0.2579 - f1-score: 0.4049 - binary_accuracy: 0.9956 - precision: 0.3737 - recall: 0.5228 - auc: 0.8148 - val_loss: 0.9577 - val_iou_score: 0.0233 - val_f1-score: 0.0423 - val_binary_accuracy: 0.9960 - val_precision: 0.2427 - val_recall: 0.0372 - val_auc: 0.5125 - lr: 1.0000e-07
# Epoch 18/30
# 30/30 [==============================] - 9s 299ms/step - loss: 0.5949 - iou_score: 0.2581 - f1-score: 0.4051 - binary_accuracy: 0.9956 - precision: 0.3740 - recall: 0.5229 - auc: 0.8148 - val_loss: 0.9584 - val_iou_score: 0.0229 - val_f1-score: 0.0416 - val_binary_accuracy: 0.9961 - val_precision: 0.2511 - val_recall: 0.0343 - val_auc: 0.5102 - lr: 1.0000e-08
# Epoch 19/30
# 30/30 [==============================] - 9s 300ms/step - loss: 0.5949 - iou_score: 0.2581 - f1-score: 0.4051 - binary_accuracy: 0.9956 - precision: 0.3740 - recall: 0.5230 - auc: 0.8148 - val_loss: 0.9599 - val_iou_score: 0.0221 - val_f1-score: 0.0401 - val_binary_accuracy: 0.9961 - val_precision: 0.2617 - val_recall: 0.0323 - val_auc: 0.5085 - lr: 1.0000e-08
# Epoch 20/30
# 30/30 [==============================] - 9s 300ms/step - loss: 0.5949 - iou_score: 0.2581 - f1-score: 0.4051 - binary_accuracy: 0.9956 - precision: 0.3741 - recall: 0.5230 - auc: 0.8148 - val_loss: 0.9603 - val_iou_score: 0.0219 - val_f1-score: 0.0397 - val_binary_accuracy: 0.9961 - val_precision: 0.2663 - val_recall: 0.0304 - val_auc: 0.5083 - lr: 1.0000e-09
# Epoch 21/30
# 30/30 [==============================] - 9s 301ms/step - loss: 0.5949 - iou_score: 0.2581 - f1-score: 0.4051 - binary_accuracy: 0.9956 - precision: 0.3741 - recall: 0.5230 - auc: 0.8149 - val_loss: 0.9609 - val_iou_score: 0.0215 - val_f1-score: 0.0391 - val_binary_accuracy: 0.9961 - val_precision: 0.2692 - val_recall: 0.0300 - val_auc: 0.5075 - lr: 1.0000e-09
# Epoch 22/30
# 30/30 [==============================] - 9s 300ms/step - loss: 0.5949 - iou_score: 0.2581 - f1-score: 0.4051 - binary_accuracy: 0.9956 - precision: 0.3741 - recall: 0.5230 - auc: 0.8148 - val_loss: 0.9613 - val_iou_score: 0.0213 - val_f1-score: 0.0387 - val_binary_accuracy: 0.9962 - val_precision: 0.2724 - val_recall: 0.0285 - val_auc: 0.5078 - lr: 1.0000e-10
# Epoch 23/30
# 30/30 [==============================] - 9s 300ms/step - loss: 0.5949 - iou_score: 0.2581 - f1-score: 0.4051 - binary_accuracy: 0.9956 - precision: 0.3741 - recall: 0.5230 - auc: 0.8148 - val_loss: 0.9618 - val_iou_score: 0.0210 - val_f1-score: 0.0382 - val_binary_accuracy: 0.9962 - val_precision: 0.2768 - val_recall: 0.0275 - val_auc: 0.5076 - lr: 1.0000e-10
# Epoch 24/30
# 30/30 [==============================] - 9s 300ms/step - loss: 0.5949 - iou_score: 0.2581 - f1-score: 0.4051 - binary_accuracy: 0.9956 - precision: 0.3741 - recall: 0.5230 - auc: 0.8148 - val_loss: 0.9623 - val_iou_score: 0.0207 - val_f1-score: 0.0377 - val_binary_accuracy: 0.9962 - val_precision: 0.2803 - val_recall: 0.0271 - val_auc: 0.5071 - lr: 1.0000e-11
# Epoch 25/30
# 30/30 [==============================] - 9s 302ms/step - loss: 0.5949 - iou_score: 0.2581 - f1-score: 0.4051 - binary_accuracy: 0.9956 - precision: 0.3741 - recall: 0.5230 - auc: 0.8149 - val_loss: 0.9625 - val_iou_score: 0.0206 - val_f1-score: 0.0375 - val_binary_accuracy: 0.9962 - val_precision: 0.2816 - val_recall: 0.0266 - val_auc: 0.5072 - lr: 1.0000e-11
# Epoch 26/30
# 30/30 [==============================] - 9s 300ms/step - loss: 0.5949 - iou_score: 0.2581 - f1-score: 0.4051 - binary_accuracy: 0.9956 - precision: 0.3741 - recall: 0.5230 - auc: 0.8148 - val_loss: 0.9627 - val_iou_score: 0.0205 - val_f1-score: 0.0373 - val_binary_accuracy: 0.9962 - val_precision: 0.2833 - val_recall: 0.0259 - val_auc: 0.5075 - lr: 1.0000e-12
# Epoch 27/30
# 30/30 [==============================] - 9s 301ms/step - loss: 0.5949 - iou_score: 0.2581 - f1-score: 0.4051 - binary_accuracy: 0.9956 - precision: 0.3741 - recall: 0.5230 - auc: 0.8148 - val_loss: 0.9628 - val_iou_score: 0.0204 - val_f1-score: 0.0372 - val_binary_accuracy: 0.9962 - val_precision: 0.2841 - val_recall: 0.0258 - val_auc: 0.5074 - lr: 1.0000e-12
# Epoch 28/30
# 30/30 [==============================] - 9s 301ms/step - loss: 0.5949 - iou_score: 0.2581 - f1-score: 0.4051 - binary_accuracy: 0.9956 - precision: 0.3741 - recall: 0.5230 - auc: 0.8148 - val_loss: 0.9621 - val_iou_score: 0.0208 - val_f1-score: 0.0379 - val_binary_accuracy: 0.9962 - val_precision: 0.2783 - val_recall: 0.0269 - val_auc: 0.5081 - lr: 1.0000e-13
# Epoch 29/30
# 30/30 [==============================] - 9s 298ms/step - loss: 0.5949 - iou_score: 0.2581 - f1-score: 0.4051 - binary_accuracy: 0.9956 - precision: 0.3741 - recall: 0.5230 - auc: 0.8148 - val_loss: 0.9621 - val_iou_score: 0.0208 - val_f1-score: 0.0379 - val_binary_accuracy: 0.9962 - val_precision: 0.2780 - val_recall: 0.0264 - val_auc: 0.5085 - lr: 1.0000e-13
# Epoch 30/30
# 30/30 [==============================] - 9s 298ms/step - loss: 0.5949 - iou_score: 0.2581 - f1-score: 0.4051 - binary_accuracy: 0.9956 - precision: 0.3741 - recall: 0.5230 - auc: 0.8148 - val_loss: 0.9620 - val_iou_score: 0.0209 - val_f1-score: 0.0380 - val_binary_accuracy: 0.9962 - val_precision: 0.2780 - val_recall: 0.0264 - val_auc: 0.5093 - lr: 1.0000e-14

# %%
#model.evaluate(x_test,y_test)
#score= model.evaluate(x_train,y_train,verbose=0)
results = model.evaluate(x_test, y_test, verbose=0)

# Retrieve and print all metrics
metrics_names = model.metrics_names
for metric_name, metric_value in zip(metrics_names, results):
    print(f"{metric_name}: {metric_value}")
# Out:
# 2023-06-10 23:54:33.539087: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.02GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-06-10 23:54:33.539149: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.02GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-06-10 23:54:33.539164: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.02GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-06-10 23:54:33.539178: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.02GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-06-10 23:54:33.539191: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.02GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-06-10 23:54:33.539204: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.02GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-06-10 23:54:33.539218: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.02GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-06-10 23:54:33.539230: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.02GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-06-10 23:54:33.539244: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.02GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-06-10 23:54:33.539258: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 6.02GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# loss: 0.9589378237724304
# iou_score: 0.020961452275514603
# f1-score: 0.04106217622756958
# binary_accuracy: 0.996184229850769
# precision: 0.2781263291835785
# recall: 0.02633613534271717
# auc: 0.2634739875793457

# %%
test_img = x_train[0]
ground_truth=y_train[0]
test_img_input=np.expand_dims(test_img, 0)
test_pred1 = model.predict(test_img_input)
test_prediction1=(test_pred1>=0.5)
test_prediction1=np.squeeze(test_prediction1,axis=-1)
test_prediction1=np.squeeze(test_prediction1,axis=0)
print(test_prediction1.shape)
# Out:
# 1/1 [==============================] - 1s 626ms/step
# (256, 256, 64)

# %%
ground_truth_argmax = ground_truth>=0.5
ground_truth_argmax = np.squeeze(ground_truth_argmax, axis = -1)
print(ground_truth_argmax.shape)
print(test_img.shape)
# Out:
# (256, 256, 64)
# (256, 256, 64, 3)

# %%
for x in range(32):
  plt.figure(figsize=(10,10)) 
  plt.subplot(221)
  plt.title('Testing Label')
  plt.imshow(ground_truth_argmax[:,:,x])
  plt.subplot(222)
  plt.title('Prediction on test image')
  plt.imshow(test_prediction1[:,:,x])
  plt.show()

# %%
test_img=nib.load(r"/home/dnn4/pythonCodeArea/soham/New_folder/resized imgs(256)/K1-img.nii.gz")
test_im=np.array(test_img.dataobj)
test_img_input=np.stack((test_im,)*3, -1)
test_img_input=np.expand_dims(test_img_input,0)
print(test_img_input.shape)
test_pred1 = model.predict(test_img_input)
test_pred1=(test_pred1>=0.5)
#test_prediction1 = np.argmax(test_pred1, axis=4)
print(test_prediction1.shape)
print(np.unique(test_pred1))
# Out:
# (1, 256, 256, 64, 3)
# 1/1 [==============================] - 1s 593ms/step
# (256, 256, 64)
# [False  True]

# %%
reconstructed_image=np.reshape(test_pred1,(256,256,64))
reconstructed_image=reconstructed_image.astype(np.uint8)

# %%
print(test_img.affine)
# Out:
# [[   2.          0.          0.       -127.      ]
#  [   0.          2.          0.       -127.      ]
#  [   0.          0.         16.546875 -481.953125]
#  [   0.          0.          0.          1.      ]]

# %%
out_img=nib.Nifti1Image(reconstructed_image,test_img.affine)
nib.save(out_img,'segmentation-output-k1-Unet(resnet50)')
